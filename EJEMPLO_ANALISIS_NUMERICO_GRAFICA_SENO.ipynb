# %% [markdown]
# <a href="https://colab.research.google.com/github/JoseAlbertoGranada/Analisis-Numerico/blob/master/EJEMPLO_ANALISIS_NUMERICO_GRAFICA_SENO.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

x = np.arange(0, 10 * np.pi, 0.1)
y = np.sin(x)
plt.plot(x, y)
